# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Открытие-файлов-и-их-изучение" data-toc-modified-id="Открытие-файлов-и-их-изучение-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Открытие файлов и их изучение</a></span></li><li><span><a href="#Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы." data-toc-modified-id="Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.</a></span></li><li><span><a href="#Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span></li><li><span><a href="#Проведите-предобработку-данных" data-toc-modified-id="Проведите-предобработку-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проведите предобработку данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы." data-toc-modified-id="Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.</a></span></li><li><span><a href="#Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной." data-toc-modified-id="Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишите-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишите-функцию-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишите функцию для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы." data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## 1. Подготовка данных

# %% [markdown]
# ### Открытие файлов и их изучение

# %%
import sklearn
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.datasets import make_regression
from sklearn.metrics import make_scorer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.dummy import DummyRegressor
from tempfile import mkdtemp
import joblib
import os

# %%
save_dir = mkdtemp()

# %%
df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
df = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
df_train[df_train.isna().any(axis=1)].head(20)
# Out:
#                     date  final.output.concentrate_ag  \
# 47   2016-01-16 23:00:00                     4.591462
# 48   2016-01-17 00:00:00                     5.296830
# 49   2016-01-17 02:00:00                     8.162896
# 65   2016-01-17 19:00:00                     5.976553
# 66   2016-01-17 20:00:00                     5.849873
# 67   2016-01-17 21:00:00                     5.608075
# 72   2016-01-18 02:00:00                     4.537821
# 96   2016-01-19 02:00:00                     2.660271
# 97   2016-01-20 16:00:00                     6.641615
# 98   2016-01-20 17:00:00                     6.583268
# 99   2016-01-20 19:00:00                     7.153846
# 100  2016-01-20 20:00:00                     6.305651
# 114  2016-01-21 10:00:00                     5.782224
# 267  2016-01-27 19:00:00                     5.666807
# 278  2016-01-28 06:00:00                     7.164662
# 279  2016-01-28 07:00:00                     8.240208
# 280  2016-01-28 08:00:00                    11.525055
# 315  2016-01-29 19:00:00                     6.216028
# 316  2016-01-29 20:00:00                     7.439060
# 317  2016-01-30 00:00:00                    10.217563
#
#      final.output.concentrate_pb  final.output.concentrate_sol  \
# 47                     10.628846                      5.688961
# 48                     10.597469                           NaN
# 49                      8.877528                           NaN
# 65                     10.996561                           NaN
# 66                     10.630010                           NaN
# 67                     10.683667                           NaN
# 72                     11.108789                      4.964392
# 96                      6.020833                      2.339234
# 97                      8.990178                           NaN
# 98                      9.204989                           NaN
# 99                      9.698348                           NaN
# 100                     9.292543                           NaN
# 114                    10.969985                      9.301260
# 267                    12.162702                     10.514352
# 278                    11.696373                           NaN
# 279                    11.873780                           NaN
# 280                    16.705297                           NaN
# 315                    10.491338                           NaN
# 316                     9.674481                           NaN
# 317                     8.213873                           NaN
#
#      final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 47                     46.663335              55.088448             10.694584
# 48                     44.015642              41.962008             11.975654
# 49                     40.715973              49.884856             10.381465
# 65                     43.523390              62.514075             11.439665
# 66                     43.582899              61.819261             11.415898
# 67                     44.966499              63.767242             11.462566
# 72                     44.631736              72.825821             10.188482
# 96                     27.097386              58.017871              5.640190
# 97                     44.161305              64.045287             12.460954
# 98                     44.480794              49.836467             12.312460
# 99                     43.066187              63.423986             11.837532
# 100                    44.188280              68.629089             11.039706
# 114                    43.181003              74.257359             11.959760
# 267                    43.782546              66.366833             11.378583
# 278                    39.982056              55.235125             11.861058
# 279                    38.469256              23.777226             10.950691
# 280                    24.851868              37.920986             10.306173
# 315                    42.600851              72.878517             11.702119
# 316                    40.859356              65.944912             12.271132
# 317                    43.448121              64.445532             11.705448
#
#      final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 47               1.671644              17.910312              2.686782  ...
# 48               1.846558               8.138408              2.889469  ...
# 49               1.024030              12.974257              2.739224  ...
# 65               1.255373               9.235768              2.770570  ...
# 66               1.373004               9.696283              2.816412  ...
# 67               1.413849              10.764420              2.755172  ...
# 72               1.410536              20.955075              2.238369  ...
# 96               0.865842               7.574660              1.505868  ...
# 97               1.905541               4.360854              3.075640  ...
# 98               1.751168               3.777035              2.938621  ...
# 99               1.593730               6.481931              3.048757  ...
# 100              1.590636              13.278665              2.883928  ...
# 114              2.064173              15.139256              3.091437  ...
# 267              1.903426              17.605365              3.498412  ...
# 278              1.342052               8.297814              2.964615  ...
# 279              1.863787              10.848724              5.631987  ...
# 280              1.467817              13.864032              5.839019  ...
# 315              1.205711               8.275870              2.476420  ...
# 316              1.405582               4.790456              2.804975  ...
# 317              1.702368               6.816273              3.677672  ...
#
#      secondary_cleaner.state.floatbank4_a_air  \
# 47                                  13.997488
# 48                                  14.006476
# 49                                  13.984906
# 65                                  14.000420
# 66                                  14.017045
# 67                                  14.038568
# 72                                  14.064474
# 96                                  13.947368
# 97                                  13.977521
# 98                                  14.055718
# 99                                  13.963388
# 100                                 13.969268
# 114                                       NaN
# 267                                 14.915689
# 278                                 14.962364
# 279                                 15.035239
# 280                                 14.990876
# 315                                 13.623560
# 316                                 12.992534
# 317                                 12.981673
#
#      secondary_cleaner.state.floatbank4_a_level  \
# 47                                  -551.224653
# 48                                  -549.388727
# 49                                  -550.563329
# 65                                  -550.369289
# 66                                  -549.905281
# 67                                  -549.818311
# 72                                  -551.573603
# 96                                  -703.993293
# 97                                  -550.386614
# 98                                  -549.694176
# 99                                  -550.169770
# 100                                 -549.873750
# 114                                         NaN
# 267                                 -550.379366
# 278                                 -552.603157
# 279                                 -551.210953
# 280                                 -550.832205
# 315                                 -499.432242
# 316                                 -498.622660
# 317                                 -500.817370
#
#      secondary_cleaner.state.floatbank4_b_air  \
# 47                                  11.971272
# 48                                  11.975967
# 49                                  11.999730
# 65                                  11.993860
# 66                                  12.002873
# 67                                  11.972607
# 72                                  11.974107
# 96                                  12.018188
# 97                                  12.000013
# 98                                  12.005398
# 99                                  12.015529
# 100                                 12.014645
# 114                                       NaN
# 267                                 12.950835
# 278                                 13.015154
# 279                                 13.006954
# 280                                 13.072333
# 315                                 13.083908
# 316                                 13.047256
# 317                                 13.033446
#
#      secondary_cleaner.state.floatbank4_b_level  \
# 47                                  -550.095619
# 48                                  -550.778624
# 49                                  -550.549773
# 65                                  -550.801872
# 66                                  -550.416734
# 67                                  -550.311739
# 72                                  -550.699412
# 96                                  -559.800324
# 97                                  -550.451984
# 98                                  -550.660760
# 99                                  -551.555211
# 100                                 -549.746603
# 114                                         NaN
# 267                                 -550.337218
# 278                                 -550.108720
# 279                                 -549.657821
# 280                                 -550.092702
# 315                                 -499.298491
# 316                                 -497.090905
# 317                                 -504.122731
#
#      secondary_cleaner.state.floatbank5_a_air  \
# 47                                   9.981163
# 48                                   9.989726
# 49                                   9.941869
# 65                                  10.019677
# 66                                   9.960796
# 67                                  10.074953
# 72                                  10.028196
# 96                                   9.999754
# 97                                   9.963179
# 98                                  10.019514
# 99                                  10.072424
# 100                                  9.971790
# 114                                       NaN
# 267                                 10.018989
# 278                                 10.050661
# 279                                 10.036625
# 280                                  9.957589
# 315                                 14.036949
# 316                                 13.966294
# 317                                 13.957035
#
#      secondary_cleaner.state.floatbank5_a_level  \
# 47                                  -502.869109
# 48                                  -499.607365
# 49                                  -503.282068
# 65                                  -502.134984
# 66                                  -497.271602
# 67                                  -500.657987
# 72                                  -500.331171
# 96                                  -512.673353
# 97                                  -500.873518
# 98                                  -501.677694
# 99                                  -499.028818
# 100                                 -498.163002
# 114                                         NaN
# 267                                 -599.770340
# 278                                 -605.892733
# 279                                 -596.638776
# 280                                 -590.919659
# 315                                 -499.790065
# 316                                 -497.920660
# 317                                 -499.149096
#
#      secondary_cleaner.state.floatbank5_b_air  \
# 47                                   7.941184
# 48                                   7.958252
# 49                                   8.018850
# 65                                   8.028135
# 66                                   8.028384
# 67                                   7.974807
# 72                                   8.072443
# 96                                   7.946763
# 97                                   8.051530
# 98                                   8.123011
# 99                                   8.075196
# 100                                  7.921794
# 114                                       NaN
# 267                                  8.046723
# 278                                  7.993430
# 279                                  7.981625
# 280                                  8.018087
# 315                                 12.628562
# 316                                 11.949566
# 317                                 11.974559
#
#      secondary_cleaner.state.floatbank5_b_level  \
# 47                                  -500.623610
# 48                                  -498.882560
# 49                                  -500.970716
# 65                                  -500.026321
# 66                                  -499.558407
# 67                                  -500.155945
# 72                                  -499.359611
# 96                                  -500.475471
# 97                                  -499.780601
# 98                                  -499.966297
# 99                                  -500.064559
# 100                                 -499.470853
# 114                                         NaN
# 267                                 -599.814004
# 278                                 -600.128409
# 279                                 -599.783550
# 280                                 -599.316783
# 315                                 -500.206739
# 316                                 -499.477679
# 317                                 -500.408153
#
#      secondary_cleaner.state.floatbank6_a_air  \
# 47                                  12.018837
# 48                                  11.967977
# 49                                  11.991078
# 65                                  11.999417
# 66                                  11.978157
# 67                                  11.985006
# 72                                  11.973959
# 96                                  11.963962
# 97                                  11.956762
# 98                                  11.995185
# 99                                  11.991893
# 100                                 11.990432
# 114                                       NaN
# 267                                 11.979329
# 278                                 11.973748
# 279                                 12.021184
# 280                                 11.993517
# 315                                 14.694700
# 316                                 14.050020
# 317                                 13.983338
#
#      secondary_cleaner.state.floatbank6_a_level
# 47                                  -600.916665
# 48                                  -599.440603
# 49                                  -598.475929
# 65                                  -601.306527
# 66                                  -598.788524
# 67                                  -600.107206
# 72                                  -600.580952
# 96                                  -607.847547
# 97                                  -599.938457
# 98                                  -601.176360
# 99                                  -598.901999
# 100                                 -600.071259
# 114                                         NaN
# 267                                 -600.452970
# 278                                 -603.013151
# 279                                 -599.515554
# 280                                 -596.586093
# 315                                 -499.911762
# 316                                 -498.618889
# 317                                 -500.237441
#
# [20 rows x 87 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
# date                                                  14149 non-null object
# final.output.concentrate_ag                           14148 non-null float64
# final.output.concentrate_pb                           14148 non-null float64
# final.output.concentrate_sol                          13938 non-null float64
# final.output.concentrate_au                           14149 non-null float64
# final.output.recovery                                 14149 non-null float64
# final.output.tail_ag                                  14149 non-null float64
# final.output.tail_pb                                  14049 non-null float64
# final.output.tail_sol                                 14144 non-null float64
# final.output.tail_au                                  14149 non-null float64
# primary_cleaner.input.sulfate                         14129 non-null float64
# primary_cleaner.input.depressant                      14117 non-null float64
# primary_cleaner.input.feed_size                       14149 non-null float64
# primary_cleaner.input.xanthate                        14049 non-null float64
# primary_cleaner.output.concentrate_ag                 14149 non-null float64
# primary_cleaner.output.concentrate_pb                 14063 non-null float64
# primary_cleaner.output.concentrate_sol                13863 non-null float64
# primary_cleaner.output.concentrate_au                 14149 non-null float64
# primary_cleaner.output.tail_ag                        14148 non-null float64
# primary_cleaner.output.tail_pb                        14134 non-null float64
# primary_cleaner.output.tail_sol                       14103 non-null float64
# primary_cleaner.output.tail_au                        14149 non-null float64
# primary_cleaner.state.floatbank8_a_air                14145 non-null float64
# primary_cleaner.state.floatbank8_a_level              14148 non-null float64
# primary_cleaner.state.floatbank8_b_air                14145 non-null float64
# primary_cleaner.state.floatbank8_b_level              14148 non-null float64
# primary_cleaner.state.floatbank8_c_air                14147 non-null float64
# primary_cleaner.state.floatbank8_c_level              14148 non-null float64
# primary_cleaner.state.floatbank8_d_air                14146 non-null float64
# primary_cleaner.state.floatbank8_d_level              14148 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         14148 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    14148 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    14148 non-null float64
# rougher.calculation.au_pb_ratio                       14149 non-null float64
# rougher.input.feed_ag                                 14149 non-null float64
# rougher.input.feed_pb                                 14049 non-null float64
# rougher.input.feed_rate                               14141 non-null float64
# rougher.input.feed_size                               14005 non-null float64
# rougher.input.feed_sol                                14071 non-null float64
# rougher.input.feed_au                                 14149 non-null float64
# rougher.input.floatbank10_sulfate                     14120 non-null float64
# rougher.input.floatbank10_xanthate                    14141 non-null float64
# rougher.input.floatbank11_sulfate                     14113 non-null float64
# rougher.input.floatbank11_xanthate                    13721 non-null float64
# rougher.output.concentrate_ag                         14149 non-null float64
# rougher.output.concentrate_pb                         14149 non-null float64
# rougher.output.concentrate_sol                        14127 non-null float64
# rougher.output.concentrate_au                         14149 non-null float64
# rougher.output.recovery                               14149 non-null float64
# rougher.output.tail_ag                                14148 non-null float64
# rougher.output.tail_pb                                14149 non-null float64
# rougher.output.tail_sol                               14149 non-null float64
# rougher.output.tail_au                                14149 non-null float64
# rougher.state.floatbank10_a_air                       14148 non-null float64
# rougher.state.floatbank10_a_level                     14148 non-null float64
# rougher.state.floatbank10_b_air                       14148 non-null float64
# rougher.state.floatbank10_b_level                     14148 non-null float64
# rougher.state.floatbank10_c_air                       14148 non-null float64
# rougher.state.floatbank10_c_level                     14148 non-null float64
# rougher.state.floatbank10_d_air                       14149 non-null float64
# rougher.state.floatbank10_d_level                     14149 non-null float64
# rougher.state.floatbank10_e_air                       13713 non-null float64
# rougher.state.floatbank10_e_level                     14149 non-null float64
# rougher.state.floatbank10_f_air                       14149 non-null float64
# rougher.state.floatbank10_f_level                     14149 non-null float64
# secondary_cleaner.output.tail_ag                      14147 non-null float64
# secondary_cleaner.output.tail_pb                      14139 non-null float64
# secondary_cleaner.output.tail_sol                     12544 non-null float64
# secondary_cleaner.output.tail_au                      14149 non-null float64
# secondary_cleaner.state.floatbank2_a_air              13932 non-null float64
# secondary_cleaner.state.floatbank2_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank2_b_air              14128 non-null float64
# secondary_cleaner.state.floatbank2_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank3_a_air              14145 non-null float64
# secondary_cleaner.state.floatbank3_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank3_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank3_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank4_a_air              14143 non-null float64
# secondary_cleaner.state.floatbank4_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank4_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank4_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank5_a_air              14148 non-null float64
# secondary_cleaner.state.floatbank5_a_level            14148 non-null float64
# secondary_cleaner.state.floatbank5_b_air              14148 non-null float64
# secondary_cleaner.state.floatbank5_b_level            14148 non-null float64
# secondary_cleaner.state.floatbank6_a_air              14147 non-null float64
# secondary_cleaner.state.floatbank6_a_level            14148 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 9.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
# date                                          5290 non-null object
# primary_cleaner.input.sulfate                 5286 non-null float64
# primary_cleaner.input.depressant              5285 non-null float64
# primary_cleaner.input.feed_size               5290 non-null float64
# primary_cleaner.input.xanthate                5286 non-null float64
# primary_cleaner.state.floatbank8_a_air        5290 non-null float64
# primary_cleaner.state.floatbank8_a_level      5290 non-null float64
# primary_cleaner.state.floatbank8_b_air        5290 non-null float64
# primary_cleaner.state.floatbank8_b_level      5290 non-null float64
# primary_cleaner.state.floatbank8_c_air        5290 non-null float64
# primary_cleaner.state.floatbank8_c_level      5290 non-null float64
# primary_cleaner.state.floatbank8_d_air        5290 non-null float64
# primary_cleaner.state.floatbank8_d_level      5290 non-null float64
# rougher.input.feed_ag                         5290 non-null float64
# rougher.input.feed_pb                         5290 non-null float64
# rougher.input.feed_rate                       5287 non-null float64
# rougher.input.feed_size                       5289 non-null float64
# rougher.input.feed_sol                        5269 non-null float64
# rougher.input.feed_au                         5290 non-null float64
# rougher.input.floatbank10_sulfate             5285 non-null float64
# rougher.input.floatbank10_xanthate            5290 non-null float64
# rougher.input.floatbank11_sulfate             5282 non-null float64
# rougher.input.floatbank11_xanthate            5265 non-null float64
# rougher.state.floatbank10_a_air               5290 non-null float64
# rougher.state.floatbank10_a_level             5290 non-null float64
# rougher.state.floatbank10_b_air               5290 non-null float64
# rougher.state.floatbank10_b_level             5290 non-null float64
# rougher.state.floatbank10_c_air               5290 non-null float64
# rougher.state.floatbank10_c_level             5290 non-null float64
# rougher.state.floatbank10_d_air               5290 non-null float64
# rougher.state.floatbank10_d_level             5290 non-null float64
# rougher.state.floatbank10_e_air               5290 non-null float64
# rougher.state.floatbank10_e_level             5290 non-null float64
# rougher.state.floatbank10_f_air               5290 non-null float64
# rougher.state.floatbank10_f_level             5290 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5287 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5290 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5288 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5290 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5281 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5290 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5290 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5290 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5290 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5290 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5290 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5290 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5290 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5290 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5290 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5290 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5290 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5290 non-null float64
# dtypes: float64(52), object(1)
# memory usage: 2.1+ MB

# %%
df_train[df_train.columns[df_train.isnull().any()]].isnull().sum().head(50)
# Out:
# final.output.concentrate_ag                              1
# final.output.concentrate_pb                              1
# final.output.concentrate_sol                           211
# final.output.tail_pb                                   100
# final.output.tail_sol                                    5
# primary_cleaner.input.sulfate                           20
# primary_cleaner.input.depressant                        32
# primary_cleaner.input.xanthate                         100
# primary_cleaner.output.concentrate_pb                   86
# primary_cleaner.output.concentrate_sol                 286
# primary_cleaner.output.tail_ag                           1
# primary_cleaner.output.tail_pb                          15
# primary_cleaner.output.tail_sol                         46
# primary_cleaner.state.floatbank8_a_air                   4
# primary_cleaner.state.floatbank8_a_level                 1
# primary_cleaner.state.floatbank8_b_air                   4
# primary_cleaner.state.floatbank8_b_level                 1
# primary_cleaner.state.floatbank8_c_air                   2
# primary_cleaner.state.floatbank8_c_level                 1
# primary_cleaner.state.floatbank8_d_air                   3
# primary_cleaner.state.floatbank8_d_level                 1
# rougher.calculation.sulfate_to_au_concentrate            1
# rougher.calculation.floatbank10_sulfate_to_au_feed       1
# rougher.calculation.floatbank11_sulfate_to_au_feed       1
# rougher.input.feed_pb                                  100
# rougher.input.feed_rate                                  8
# rougher.input.feed_size                                144
# rougher.input.feed_sol                                  78
# rougher.input.floatbank10_sulfate                       29
# rougher.input.floatbank10_xanthate                       8
# rougher.input.floatbank11_sulfate                       36
# rougher.input.floatbank11_xanthate                     428
# rougher.output.concentrate_sol                          22
# rougher.output.tail_ag                                   1
# rougher.state.floatbank10_a_air                          1
# rougher.state.floatbank10_a_level                        1
# rougher.state.floatbank10_b_air                          1
# rougher.state.floatbank10_b_level                        1
# rougher.state.floatbank10_c_air                          1
# rougher.state.floatbank10_c_level                        1
# rougher.state.floatbank10_e_air                        436
# secondary_cleaner.output.tail_ag                         2
# secondary_cleaner.output.tail_pb                        10
# secondary_cleaner.output.tail_sol                     1605
# secondary_cleaner.state.floatbank2_a_air               217
# secondary_cleaner.state.floatbank2_a_level               1
# secondary_cleaner.state.floatbank2_b_air                21
# secondary_cleaner.state.floatbank2_b_level               1
# secondary_cleaner.state.floatbank3_a_air                 4
# secondary_cleaner.state.floatbank3_a_level               1
# dtype: int64

# %% [markdown]
# **Вывод**
#
# Видно что:
# 1) в `df_train` кол-во колонок больше чем в `df_test`
# 2) Данные пропущены в обоих датасетах
# 3) Коол-во пропусков варьируется в зависимости от колонки в достаточно больших диапазонах от 1 до 1000 и более

# %% [markdown]
# ### Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.

# %%
Rec_train = df_train['rougher.output.recovery']

# %%
C = df_train['rougher.output.concentrate_au']
F = df_train['rougher.input.feed_au']
T = df_train['rougher.output.tail_au']

# %%
Rec_measured = (C * (F - T))/ (F * (C - T)) * 100

# %%
mean_absolute_error(Rec_train, Rec_measured)
# Out:
# 9.682896147825551e-15

# %%
df_train[~df_train.isna()]
# Out:
#                       date  final.output.concentrate_ag  \
# 0      2016-01-15 00:00:00                     6.055403
# 1      2016-01-15 01:00:00                     6.029369
# 2      2016-01-15 02:00:00                     6.055926
# 3      2016-01-15 03:00:00                     6.047977
# 4      2016-01-15 04:00:00                     6.148599
# ...                    ...                          ...
# 14144  2018-08-18 06:59:59                     3.224920
# 14145  2018-08-18 07:59:59                     3.195978
# 14146  2018-08-18 08:59:59                     3.109998
# 14147  2018-08-18 09:59:59                     3.367241
# 14148  2018-08-18 10:59:59                     3.598375
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                         9.889648                      5.507324
# 1                         9.968944                      5.257781
# 2                        10.213995                      5.383759
# 3                         9.977019                      4.858634
# 4                        10.142511                      4.939416
# ...                            ...                           ...
# 14144                    11.356233                      6.803482
# 14145                    11.349355                      6.862249
# 14146                    11.434366                      6.886013
# 14147                    11.625587                      6.799433
# 14148                    11.737832                      6.717509
#
#        final.output.concentrate_au  final.output.recovery  \
# 0                        42.192020              70.541216
# 1                        42.701629              69.266198
# 2                        42.657501              68.116445
# 3                        42.689819              68.347543
# 4                        42.774141              66.927016
# ...                            ...                    ...
# 14144                    46.713954              73.755150
# 14145                    46.866780              69.049291
# 14146                    46.795691              67.002189
# 14147                    46.408188              65.523246
# 14148                    46.299438              70.281454
#
#        final.output.tail_ag  final.output.tail_pb  final.output.tail_sol  \
# 0                 10.411962              0.895447              16.904297
# 1                 10.462676              0.927452              16.634514
# 2                 10.507046              0.953716              16.208849
# 3                 10.422762              0.883763              16.532835
# 4                 10.360302              0.792826              16.525686
# ...                     ...                   ...                    ...
# 14144              8.769645              3.141541              10.403181
# 14145              8.897321              3.130493              10.549470
# 14146              8.529606              2.911418              11.115147
# 14147              8.777171              2.819214              10.463847
# 14148              8.406690              2.517518              10.652193
#
#        final.output.tail_au  ...  secondary_cleaner.state.floatbank4_a_air  \
# 0                  2.143149  ...                                 14.016835
# 1                  2.224930  ...                                 13.992281
# 2                  2.257889  ...                                 14.015015
# 3                  2.146849  ...                                 14.036510
# 4                  2.055292  ...                                 14.027298
# ...                     ...  ...                                       ...
# 14144              1.529220  ...                                 23.031497
# 14145              1.612542  ...                                 22.960095
# 14146              1.596616  ...                                 23.015718
# 14147              1.602879  ...                                 23.024963
# 14148              1.389434  ...                                 23.018622
#
#        secondary_cleaner.state.floatbank4_a_level  \
# 0                                     -502.488007
# 1                                     -505.503262
# 2                                     -502.520901
# 3                                     -500.857308
# 4                                     -499.838632
# ...                                           ...
# 14144                                 -501.167942
# 14145                                 -501.612783
# 14146                                 -501.711599
# 14147                                 -501.153409
# 14148                                 -500.492702
#
#        secondary_cleaner.state.floatbank4_b_air  \
# 0                                     12.099931
# 1                                     11.950531
# 2                                     11.912783
# 3                                     11.999550
# 4                                     11.953070
# ...                                         ...
# 14144                                 20.007571
# 14145                                 20.035660
# 14146                                 19.951231
# 14147                                 20.054122
# 14148                                 20.020205
#
#        secondary_cleaner.state.floatbank4_b_level  \
# 0                                     -504.715942
# 1                                     -501.331529
# 2                                     -501.133383
# 3                                     -501.193686
# 4                                     -501.053894
# ...                                           ...
# 14144                                 -499.740028
# 14145                                 -500.251357
# 14146                                 -499.857027
# 14147                                 -500.314711
# 14148                                 -500.220296
#
#        secondary_cleaner.state.floatbank5_a_air  \
# 0                                      9.925633
# 1                                     10.039245
# 2                                     10.070913
# 3                                      9.970366
# 4                                      9.925709
# ...                                         ...
# 14144                                 18.006038
# 14145                                 17.998535
# 14146                                 18.019543
# 14147                                 17.979515
# 14148                                 17.963512
#
#        secondary_cleaner.state.floatbank5_a_level  \
# 0                                     -498.310211
# 1                                     -500.169983
# 2                                     -500.129135
# 3                                     -499.201640
# 4                                     -501.686727
# ...                                           ...
# 14144                                 -499.834374
# 14145                                 -500.395178
# 14146                                 -500.451156
# 14147                                 -499.272871
# 14148                                 -499.939490
#
#        secondary_cleaner.state.floatbank5_b_air  \
# 0                                      8.079666
# 1                                      7.984757
# 2                                      8.013877
# 3                                      7.977324
# 4                                      7.894242
# ...                                         ...
# 14144                                 13.001114
# 14145                                 12.954048
# 14146                                 13.023431
# 14147                                 12.992404
# 14148                                 12.990306
#
#        secondary_cleaner.state.floatbank5_b_level  \
# 0                                     -500.470978
# 1                                     -500.582168
# 2                                     -500.517572
# 3                                     -500.255908
# 4                                     -500.356035
# ...                                           ...
# 14144                                 -500.155694
# 14145                                 -499.895163
# 14146                                 -499.914391
# 14147                                 -499.976268
# 14148                                 -500.080993
#
#        secondary_cleaner.state.floatbank6_a_air  \
# 0                                     14.151341
# 1                                     13.998353
# 2                                     14.028663
# 3                                     14.005551
# 4                                     13.996647
# ...                                         ...
# 14144                                 20.007840
# 14145                                 19.968498
# 14146                                 19.990885
# 14147                                 20.013986
# 14148                                 19.990336
#
#        secondary_cleaner.state.floatbank6_a_level
# 0                                     -605.841980
# 1                                     -599.787184
# 2                                     -601.427363
# 3                                     -599.996129
# 4                                     -601.496691
# ...                                           ...
# 14144                                 -501.296428
# 14145                                 -501.041608
# 14146                                 -501.518452
# 14147                                 -500.625471
# 14148                                 -499.191575
#
# [14149 rows x 87 columns]

# %% [markdown]
# **Комментарий**
#
# Значение MAE достаточно маленькое чтобы говорить о каких лиюо значительных различиях между расчитанной нами и значениями в таблице величины `rougher.output.recovery`.

# %% [markdown]
# ### Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
col_only_train = df_train.columns[~df_train.columns.isin(df_test.columns)]
print(col_only_train)
# Out:
# Index(['final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb',
#        'final.output.tail_sol', 'final.output.tail_au',
#        'primary_cleaner.output.concentrate_ag',
#        'primary_cleaner.output.concentrate_pb',
#        'primary_cleaner.output.concentrate_sol',
#        'primary_cleaner.output.concentrate_au',
#        'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb',
#        'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au',
#        'rougher.calculation.sulfate_to_au_concentrate',
#        'rougher.calculation.floatbank10_sulfate_to_au_feed',
#        'rougher.calculation.floatbank11_sulfate_to_au_feed',
#        'rougher.calculation.au_pb_ratio', 'rougher.output.concentrate_ag',
#        'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol',
#        'rougher.output.concentrate_au', 'rougher.output.recovery',
#        'rougher.output.tail_ag', 'rougher.output.tail_pb',
#        'rougher.output.tail_sol', 'rougher.output.tail_au',
#        'secondary_cleaner.output.tail_ag', 'secondary_cleaner.output.tail_pb',
#        'secondary_cleaner.output.tail_sol',
#        'secondary_cleaner.output.tail_au'],
#       dtype='object')

# %% [markdown]
# **Комментарий**
#
# Видно что колонки отсутсвутющие в `df_test` в основном касаются выходных данных(т.е c типом параметра output), что в целом наверно логично ибо насколько я понял в тестовом наборе данных указаны лишь параметры которые известны лишь в начале, соответственно итоговые значения нам не должны быть известны(так как мы их по сути предсказываем)

# %% [markdown]
# ### Проведите предобработку данных

# %% [markdown]
# Заполняем методом ffill т.к соседние по времени параметры часто похожи(так было сказано в условие)

# %%
# for i in df_train[df_train.isna().any(axis=1)].index:
#     print(df_train.loc[i][df_train[df_train.isna().any(axis=1)].loc[i].isna()], '\n')

# %%
df_train.fillna(method='ffill', inplace=True)

# %%
df_test.fillna(method='ffill', inplace=True)

# %% [markdown]
# ## 2. Анализ данных

# %% [markdown]
# ### Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.

# %% [markdown]
# **Флотация**

# %%
for i in ['ag', 'au', 'pb']:
    globals()[f'{i}_flotation'] = df_train[f'rougher.output.concentrate_{i}'] - df_train[f'rougher.input.feed_{i}']
    print(
        f'Разница концентраций для {i}-элемента между конечным и исходными концентрациями равна','\n',
        globals()[f'{i}_flotation'])
# Out:
# Разница концентраций для ag-элемента между конечным и исходными концентрациями равна
#  0        5.400393
# 1        5.454752
# 2        5.579298
# 3        5.871738
# 4        6.350138
#            ...
# 14144    5.033042
# 14145    5.304661
# 14146    2.552982
# 14147    5.610668
# 14148    5.800768
# Length: 14149, dtype: float64
# Разница концентраций для au-элемента между конечным и исходными концентрациями равна
#  0        13.307658
# 1        13.572392
# 2        13.374948
# 3        13.202621
# 4        13.552394
#            ...
# 14144    13.267688
# 14145    13.602816
# 14146    10.586170
# 14147    13.471991
# 14148    13.438643
# Length: 14149, dtype: float64
# Разница концентраций для pb-элемента между конечным и исходными концентрациями равна
#  0        4.816162
# 1        5.012774
# 2        5.057211
# 3        5.137809
# 4        5.453330
#            ...
# 14144    6.366444
# 14145    6.743224
# 14146    4.935132
# 14147    6.752840
# 14148    6.826422
# Length: 14149, dtype: float64

# %% [markdown]
# **Первичным этап очистки**

# %%
for i in ['ag', 'au', 'pb']:
    print(
        f'Разница концентраций для {i}-элемента между конечным и исходными концентрациями во время первичной очистки равна','\n',
        df_train[f'primary_cleaner.output.concentrate_{i}'] - df_train[f'rougher.output.concentrate_{i}'])
# Out:
# Разница концентраций для ag-элемента между конечным и исходными концентрациями во время первичной очистки равна
#  0       -2.953219
# 1       -3.057122
# 2       -3.092248
# 3       -4.693168
# 4       -3.321626
#            ...
# 14144   -4.565723
# 14145   -4.813607
# 14146   -1.394601
# 14147   -4.168354
# 14148   -4.421901
# Length: 14149, dtype: float64
# Разница концентраций для au-элемента между конечным и исходными концентрациями во время первичной очистки равна
#  0        14.380619
# 1        14.067550
# 2        14.232294
# 3         8.939932
# 4        13.828832
#            ...
# 14144    14.336665
# 14145    14.483889
# 14146    16.745511
# 14147    12.936120
# 14148    12.552484
# Length: 14149, dtype: float64
# Разница концентраций для pb-элемента между конечным и исходными концентрациями во время первичной очистки равна
#  0        3.288574
# 1        3.218262
# 2        3.137662
# 3        1.320947
# 4        2.746581
#            ...
# 14144    1.461963
# 14145    1.735735
# 14146    3.678423
# 14147    1.357001
# 14148    0.948137
# Length: 14149, dtype: float64

# %% [markdown]
# **Вторичный этап очистки**

# %%
for i in ['ag', 'au', 'pb']:
    print(
        f'Разница концентраций для {i}-элемента между конечным и исходными концентрациями во время первичной очистки равна','\n',
        df_train[f'final.output.concentrate_{i}'] - df_train[f'primary_cleaner.output.concentrate_{i}'])
# Out:
# Разница концентраций для ag-элемента между конечным и исходными концентрациями во время первичной очистки равна
#  0       -2.492148
# 1       -2.529375
# 2       -2.547579
# 3       -1.173902
# 4       -2.940828
#            ...
# 14144   -3.334253
# 14145   -3.416398
# 14146   -4.018899
# 14147   -4.123203
# 14148   -3.939209
# Length: 14149, dtype: float64
# Разница концентраций для au-элемента между конечным и исходными концентрациями во время первичной очистки равна
#  0         8.017593
# 1         8.583104
# 2         8.688036
# 3        14.429077
# 4         9.729208
#            ...
# 14144    13.773739
# 14145    13.941455
# 14146    14.938949
# 14147    15.637296
# 14148    15.942820
# Length: 14149, dtype: float64
# Разница концентраций для pb-элемента между конечным и исходными концентрациями во время первичной очистки равна
#  0       -0.500000
# 1       -0.528125
# 2       -0.140500
# 3        1.480455
# 4        0.155725
#            ...
# 14144   -1.089733
# 14145   -1.274593
# 14146   -1.199192
# 14147   -0.386791
# 14148    0.087547
# Length: 14149, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Получилось сделать, но не нашел способов как сделать это без повторений кода..

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
metals = ['ag', 'au', 'pb']

# %%
from matplotlib.pyplot import figure

# %%
metal = metals[0]
columns = ['rougher.output.concentrate_', 'primary_cleaner.output.concentrate_', 'final.output.concentrate_']
for j in columns:
    subset = df_train[j+metal]
    sns.distplot(subset, hist = False, kde = True,
            kde_kws = {'linewidth': 1, 'shade': True},
            label = j+i)
        
    # Plot formatting
    plt.legend(prop={'size': 11}, title = 'Этап')
    plt.title(f'Распределение концетрации {metal} на разных этапах очистки')
    plt.xlabel('Процент веществ')
    plt.ylabel('Плотность')

# %%
metal = metals[1]
columns = ['rougher.output.concentrate_', 'primary_cleaner.output.concentrate_', 'final.output.concentrate_']
for j in columns:
    subset = df_train[j+metal]
    sns.distplot(subset, hist = False, kde = True,
            kde_kws = {'linewidth': 1, 'shade': True},
            label = j+i)
        
    # Plot formatting
    plt.legend(prop={'size': 11}, title = 'Этап')
    plt.title(f'Распределение концетрации {metal} на разных этапах очистки')
    plt.xlabel('Процент веществ')
    plt.ylabel('Плотность')

# %%
metal = metals[2]
columns = ['rougher.output.concentrate_', 'primary_cleaner.output.concentrate_', 'final.output.concentrate_']
for j in columns:
    subset = df_train[j+metal]
    sns.distplot(subset, hist = False, kde = True,
            kde_kws = {'linewidth': 1, 'shade': True},
            label = j+i)
        
    # Plot formatting
    plt.legend(prop={'size': 11}, title = 'Этап')
    plt.title(f'Распределение концетрации {metal} на разных этапах очистки')
    plt.xlabel('Процент веществ')
    plt.ylabel('Плотность')

# %% [markdown]
# Можно заметить что концетрация целевого металла а именно золота, повышается по мере прохождения через стадии обработки, в отличие от других металлов коцентрация которых в конце либо становится меньше либо немного повышается в стравнение с начальными концентрациями

# %% [markdown]
# ### Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
ax = df_train.plot(kind='hist', y='rougher.input.feed_size',range=(0, 150), bins=30,linewidth=5, alpha=0.7, label='train')
df_test.plot(kind='hist', y='rougher.input.feed_size',range=(0, 150), bins=30 ,linewidth=5, alpha=0.7, label='test' , ax=ax)

# %%
# ax = df_train.sample(frac=0.36, random_state=12345).plot(kind='hist', y='rougher.input.feed_size',range=(0, 150), bins=30,linewidth=5, alpha=0.7, label='train')
# df_test.plot(kind='hist', y='rougher.input.feed_size',range=(0, 150), bins=30 ,linewidth=5, alpha=0.7, label='test' , ax=ax)

# %% [markdown]
# Видно что распределения похожи(т.к концы одинаковые и разница именно в середине распределения куда из за того что в тестовой выборке просто меньше данных, а то что пик меньше именно в середине, ем более подтвержает что распределения похожи)

# %% [markdown]
# ### Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
df_train['rougher.input.sum'] = (df_train['rougher.input.feed_ag']
 + df_train['rougher.input.feed_au']
 + df_train['rougher.input.feed_pb']
 + df_train['rougher.input.feed_sol'])

# %%
df_train['rougher.input.sum'].plot(kind='hist', alpha=0.5, grid=True, bins=40)

# %%
df_train['rougher.output.sum'] = (df_train['rougher.output.concentrate_ag'] 
 + df_train['rougher.output.concentrate_au'] 
 + df_train['rougher.output.concentrate_sol']
 + df_train['rougher.output.concentrate_pb'])

# %%
df_train['rougher.output.sum'].plot(kind='hist', alpha=0.5, grid=True, bins=40)

# %%
df_train['primary_cleaner.output.sum'] = (df_train['primary_cleaner.output.concentrate_ag'] 
 + df_train['primary_cleaner.output.concentrate_au'] 
 + df_train['primary_cleaner.output.concentrate_pb'] 
 + df_train['primary_cleaner.output.concentrate_sol'])

# %%
df_train['primary_cleaner.output.sum'].plot(kind='hist', alpha=0.5, grid=True, bins=40)

# %%
df_train['final.output.sum'] = (df_train['final.output.concentrate_ag'] 
 + df_train['final.output.concentrate_au'] 
 + df_train['final.output.concentrate_pb'] 
 + df_train['final.output.concentrate_sol'])

# %%
df_train['final.output.sum'].plot(kind='hist', alpha=0.5, grid=True, bins=40)

# %%
df_train[df_train['final.output.sum'] < 7]
# Out:
#                       date  final.output.concentrate_ag  \
# 644    2016-02-13 11:00:00                     0.000000
# 1193   2016-03-11 10:00:00                     0.000000
# 1194   2016-03-11 11:00:00                     0.000000
# 1195   2016-03-11 12:00:00                     0.000000
# 1196   2016-03-11 13:00:00                     0.000000
# ...                    ...                          ...
# 9893   2018-01-15 20:59:59                     0.000000
# 9894   2018-01-15 21:59:59                     0.000000
# 10020  2018-01-25 10:59:59                     0.000000
# 12277  2018-05-15 04:59:59                     0.010000
# 13919  2018-08-08 04:59:59                     0.289059
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 644                       0.000000                      0.000000
# 1193                      0.000000                      0.000000
# 1194                      0.000000                      0.000000
# 1195                      0.000000                      0.000000
# 1196                      0.000000                      0.000000
# ...                            ...                           ...
# 9893                      0.000000                      0.000000
# 9894                      0.000000                      0.000000
# 10020                     0.000000                      0.000000
# 12277                     0.010000                      0.010000
# 13919                     0.332391                      0.291099
#
#        final.output.concentrate_au  final.output.recovery  \
# 644                       0.000000               0.000000
# 1193                      0.000000               0.000000
# 1194                      0.000000               0.000000
# 1195                      0.000000               0.000000
# 1196                      0.000000               0.000000
# ...                            ...                    ...
# 9893                      0.000000               0.000000
# 9894                      0.000000               0.000000
# 10020                     0.000000               0.000000
# 12277                     0.010000               0.168611
# 13919                     1.063992             100.000000
#
#        final.output.tail_ag  final.output.tail_pb  final.output.tail_sol  \
# 644                8.894029              0.843584              15.417342
# 1193              10.817313              1.462800              16.407607
# 1194              10.436792              1.207636              17.800392
# 1195              10.637073              1.405778              17.195897
# 1196              10.530320              1.461550              17.556860
# ...                     ...                   ...                    ...
# 9893              11.408594              2.205271               3.469389
# 9894              10.738721              1.426022               6.409904
# 10020              2.444457              0.612787               1.751687
# 12277              8.069722              1.734258               5.262840
# 13919              0.000000              0.000000               0.000000
#
#        final.output.tail_au  ...  secondary_cleaner.state.floatbank5_a_air  \
# 644                1.779052  ...                                 22.995012
# 1193               2.984504  ...                                 11.982937
# 1194               2.747294  ...                                 11.844983
# 1195               2.791440  ...                                 12.091144
# 1196               2.682127  ...                                 12.078809
# ...                     ...  ...                                       ...
# 9893               5.819537  ...                                 11.002853
# 9894               3.837274  ...                                 11.033133
# 10020              1.210944  ...                                 10.929622
# 12277              2.452356  ...                                 24.992438
# 13919              0.000000  ...                                 22.977740
#
#        secondary_cleaner.state.floatbank5_a_level  \
# 644                                   -399.370680
# 1193                                  -449.856468
# 1194                                  -450.881424
# 1195                                  -496.404140
# 1196                                  -499.903743
# ...                                           ...
# 9893                                  -500.029477
# 9894                                  -500.405550
# 10020                                 -499.380783
# 12277                                 -503.865882
# 13919                                 -499.693120
#
#        secondary_cleaner.state.floatbank5_b_air  \
# 644                                   20.966863
# 1193                                   9.927727
# 1194                                   9.916784
# 1195                                   9.976074
# 1196                                  10.075259
# ...                                         ...
# 9893                                   9.006599
# 9894                                   9.025031
# 10020                                  9.016132
# 12277                                 23.019383
# 13919                                 18.018246
#
#        secondary_cleaner.state.floatbank5_b_level  \
# 644                                   -399.308354
# 1193                                  -450.521700
# 1194                                  -449.542871
# 1195                                  -496.783155
# 1196                                  -499.540325
# ...                                           ...
# 9893                                  -499.812437
# 9894                                  -500.224485
# 10020                                 -500.127563
# 12277                                 -500.472409
# 13919                                 -499.862852
#
#        secondary_cleaner.state.floatbank6_a_air  \
# 644                                   24.987274
# 1193                                  19.971682
# 1194                                  20.004767
# 1195                                  19.921634
# 1196                                  20.039788
# ...                                         ...
# 9893                                  10.981683
# 9894                                  10.997373
# 10020                                 10.996343
# 12277                                 25.002424
# 13919                                 23.036053
#
#        secondary_cleaner.state.floatbank6_a_level  rougher.input.sum  \
# 644                                   -399.619808          46.703740
# 1193                                  -500.685521          53.368945
# 1194                                  -500.137068          51.963364
# 1195                                  -500.769011          48.892687
# 1196                                  -499.932405          49.265736
# ...                                           ...                ...
# 9893                                  -499.607997          52.381155
# 9894                                  -500.277262          59.410599
# 10020                                 -500.089294          33.929636
# 12277                                 -503.326766           9.514401
# 13919                                 -630.786573          55.607257
#
#        rougher.output.sum  primary_cleaner.output.sum  final.output.sum
# 644             56.574778                   53.725613           0.00000
# 1193            61.681632                   61.254172           0.00000
# 1194            60.214950                   60.410868           0.00000
# 1195            58.592426                   60.154484           0.00000
# 1196            58.363177                   59.909714           0.00000
# ...                   ...                         ...               ...
# 9893            74.243066                   16.240722           0.00000
# 9894            79.597733                   61.584073           0.00000
# 10020           49.797341                   15.124596           0.00000
# 12277           12.490444                   41.272277           0.04000
# 13919           84.574105                   56.518279           1.97654
#
# [61 rows x 91 columns]

# %% [markdown]
# Можно заметить что в данных есть странные выбросы которые не совсем понятно откуда взялись, попробуем посмотреть что же с этими данными не так возможно сравнение нормальных данных с аномальными даст нам некую картину происходящего и возможно получится что это вовсе не выбросы а нормальные значения. Сперва посмотрим на данные после флотации (колонка `rougher.output.sum`), для этого сделаем отсечку на значениях из этой таблицы < 5 (т.е аномальные значения), и значения > 60 (т.е нормальные значения). После этого вычтем для каждого обьекта соответвующие признаки, перед этим применив метод `.reset_index`, чтобы не возникало проблем с индексами, и затем посмотрим на среднее для полученных значений, возможно в данных изначально 'затесалось', что то непонятное

# %%
roug = [i for i in df_train.columns if 'rougher' in i]

# %%
less = df_train[df_train['rougher.output.sum'] < 5][roug].reset_index(drop=True)

# %%
less.shape
# Out:
# (303, 37)

# %%
more = df_train[df_train['rougher.output.sum'] > 60][roug].reset_index(drop=True).loc[0:302]

# %%
for i in roug:
    print(f'{i} : ', (more-less)[i].mean())
# Out:
# rougher.calculation.sulfate_to_au_concentrate :  253.085405837043
# rougher.calculation.floatbank10_sulfate_to_au_feed :  -1806.1510613815203
# rougher.calculation.floatbank11_sulfate_to_au_feed :  -1235.082218731432
# rougher.calculation.au_pb_ratio :  0.10140757035339214
# rougher.input.feed_ag :  0.07958284456722572
# rougher.input.feed_pb :  -0.2180417048131231
# rougher.input.feed_rate :  155.6055914281232
# rougher.input.feed_size :  2.8534631903588106
# rougher.input.feed_sol :  3.5547765209853672
# rougher.input.feed_au :  -0.06286806342813493
# rougher.input.floatbank10_sulfate :  -1.1029576055844732
# rougher.input.floatbank10_xanthate :  2.1235869474991986
# rougher.input.floatbank11_sulfate :  -0.28228115718106306
# rougher.input.floatbank11_xanthate :  2.221793983937857
# rougher.output.concentrate_ag :  12.202153146542859
# rougher.output.concentrate_pb :  7.981099479101686
# rougher.output.concentrate_sol :  28.278619968333334
# rougher.output.concentrate_au :  19.521562953069317
# rougher.output.recovery :  80.2583920725159
# rougher.output.tail_ag :  -0.3232719673034653
# rougher.output.tail_pb :  0.26842563407532066
# rougher.output.tail_sol :  2.525929888543561
# rougher.output.tail_au :  0.42523626077582966
# rougher.state.floatbank10_a_air :  -203.02289685858682
# rougher.state.floatbank10_a_level :  -182.40987919443847
# rougher.state.floatbank10_b_air :  358.17418566485156
# rougher.state.floatbank10_b_level :  -11.325700359129382
# rougher.state.floatbank10_c_air :  374.95105366613683
# rougher.state.floatbank10_c_level :  -12.18775427884844
# rougher.state.floatbank10_d_air :  368.3176245627561
# rougher.state.floatbank10_d_level :  -17.608339611930028
# rougher.state.floatbank10_e_air :  306.42280951120915
# rougher.state.floatbank10_e_level :  -17.436668524938323
# rougher.state.floatbank10_f_air :  296.27464027157663
# rougher.state.floatbank10_f_level :  -17.388451040210494
# rougher.input.sum :  3.3534495973113345
# rougher.output.sum :  67.98343554704722

# %% [markdown]
# Можно заметить что присутсвутют огромные разницы в некоторых признаках, достигающие порой 1000 и более, в то же время видна заметная разница между значениями `tail`где по сути и должны быть по сути те металлы что не попали в черновой концентрат, но видно что разница мала. Получается что у нас просто пропали наши металлы куда то, поэтому мне кажется что возникновение таких аномалий ни что иное как лаги самих датчиков. В следствие этого стоит удалить такие данные

# %%
pr = [x for x in df_train.columns if 'primary_cleaner' in x]

# %%
less = df_train[df_train['primary_cleaner.output.sum'] < 1][[x for x in df_train.columns if 'primary_cleaner' in x]].reset_index(drop=True)

# %%
more = df_train[df_train['primary_cleaner.output.sum'] > 60][[x for x in df_train.columns if 'primary_cleaner' in x]].reset_index(drop=True).loc[0:193]

# %%
for i in [x for x in df_train.columns if 'primary_cleaner' in x]:
    print(f'{i} : ', (more-less)[i].mean())
# Out:
# primary_cleaner.input.sulfate :  59.28580185287079
# primary_cleaner.input.depressant :  6.651741263923693
# primary_cleaner.input.feed_size :  0.30810996816095626
# primary_cleaner.input.xanthate :  0.13645281187127276
# primary_cleaner.output.concentrate_ag :  9.555088980974407
# primary_cleaner.output.concentrate_pb :  10.30196430771667
# primary_cleaner.output.concentrate_sol :  18.820601745339918
# primary_cleaner.output.concentrate_au :  33.55682454718271
# primary_cleaner.output.tail_ag :  -0.8836811491718249
# primary_cleaner.output.tail_pb :  -0.23930214426339913
# primary_cleaner.output.tail_sol :  1.9410474988106
# primary_cleaner.output.tail_au :  -0.5720465295127705
# primary_cleaner.state.floatbank8_a_air :  -66.62585291511976
# primary_cleaner.state.floatbank8_a_level :  -0.5423789680771522
# primary_cleaner.state.floatbank8_b_air :  -74.21357805318515
# primary_cleaner.state.floatbank8_b_level :  -14.180794634171564
# primary_cleaner.state.floatbank8_c_air :  -100.81041139926784
# primary_cleaner.state.floatbank8_c_level :  4.484246652217074
# primary_cleaner.state.floatbank8_d_air :  -79.60012512285783
# primary_cleaner.state.floatbank8_d_level :  -22.387205467102174
# primary_cleaner.output.sum :  72.2344795812137

# %% [markdown]
# Наблюдаем что отклонения в похожих колонках присутсвуют, при этом опять же в tail незначительные отличия, поэтому решим что скорее всего нужно выбросить хвосты, т.к уж очень они подозрительные и неправдаподобные

# %%
df_train[['rougher.output.sum', 'final.output.sum', 'primary_cleaner.output.sum']].boxplot()

# %%
id1 = df_train[df_train['rougher.output.sum'] < 40].index

# %%
id2 = df_train[df_train['primary_cleaner.output.sum'] < 40].index

# %%
id3 = df_train[df_train['final.output.sum'] < 40].index

# %%
all_id = id1.union(id2).union(id3)

# %%
df_train.drop(all_id, inplace=True)

# %% [markdown]
# **Комментарий**
#
# Смотря на графики boxplot-ов я в целом убеждаюсь в правильности того как я сделал срезы. Т.е то что я срезал значения <5 в целом не сильно портит хвосты и мы избавляемся от нулей

# %% [markdown]
# ## 3. Модель

# %% [markdown]
# ### Напишите функцию для вычисления итоговой sMAPE.

# %%
def smape(true_val, predict):
    rougher, final = ((abs(true_val - predict) / ((abs(true_val) + abs(predict))/2)).mean() * 100)
    res = 0.25 * rougher + 0.75 * final
    return res

# %%
custom_scorer = make_scorer(smape, greater_is_better=False)

# %%
target_train = df_train[['rougher.output.recovery', 'final.output.recovery']]
features_train = df_train[df_train.columns[df_train.columns.isin(df_test.columns)]].drop(['date'], axis=1)
target_test = df.set_index('date').loc[df_test.set_index('date').index,
                                       ['rougher.output.recovery','final.output.recovery']].reset_index(drop=True)
features_test=df_test.drop(['date'], axis=1)

# %%
features_test
# Out:
#       primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                        210.800909                         14.993118
# 1                        215.392455                         14.987471
# 2                        215.259946                         12.884934
# 3                        215.336236                         12.006805
# 4                        199.099327                         10.682530
# ...                             ...                               ...
# 5285                     173.957757                         15.963399
# 5286                     172.910270                         16.002605
# 5287                     171.135718                         15.993669
# 5288                     179.697158                         15.438979
# 5289                     181.556856                         14.995850
#
#       primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                            8.080000                        1.005021
# 1                            8.080000                        0.990469
# 2                            7.786667                        0.996043
# 3                            7.640000                        0.863514
# 4                            7.530000                        0.805575
# ...                               ...                             ...
# 5285                         8.070000                        0.896701
# 5286                         8.070000                        0.896519
# 5287                         8.070000                        1.165996
# 5288                         8.070000                        1.501068
# 5289                         8.070000                        1.623454
#
#       primary_cleaner.state.floatbank8_a_air  \
# 0                                1398.981301
# 1                                1398.777912
# 2                                1398.493666
# 3                                1399.618111
# 4                                1401.268123
# ...                                      ...
# 5285                             1401.930554
# 5286                             1447.075722
# 5287                             1498.836182
# 5288                             1498.466243
# 5289                             1498.096303
#
#       primary_cleaner.state.floatbank8_a_level  \
# 0                                  -500.225577
# 1                                  -500.057435
# 2                                  -500.868360
# 3                                  -498.863574
# 4                                  -500.808305
# ...                                        ...
# 5285                               -499.728848
# 5286                               -494.716823
# 5287                               -501.770403
# 5288                               -500.483984
# 5289                               -499.796922
#
#       primary_cleaner.state.floatbank8_b_air  \
# 0                                1399.144926
# 1                                1398.055362
# 2                                1398.860436
# 3                                1397.440120
# 4                                1398.128818
# ...                                      ...
# 5285                             1401.441445
# 5286                             1448.851892
# 5287                             1499.572353
# 5288                             1497.986986
# 5289                             1501.743791
#
#       primary_cleaner.state.floatbank8_b_level  \
# 0                                  -499.919735
# 1                                  -499.778182
# 2                                  -499.764529
# 3                                  -499.211024
# 4                                  -499.504543
# ...                                        ...
# 5285                               -499.193423
# 5286                               -465.963026
# 5287                               -495.516347
# 5288                               -519.200340
# 5289                               -505.146931
#
#       primary_cleaner.state.floatbank8_c_air  \
# 0                                1400.102998
# 1                                1396.151033
# 2                                1398.075709
# 3                                1400.129303
# 4                                1402.172226
# ...                                      ...
# 5285                             1399.810313
# 5286                             1443.890424
# 5287                             1502.749213
# 5288                             1496.569047
# 5289                             1499.535978
#
#       primary_cleaner.state.floatbank8_c_level  ...  \
# 0                                  -500.704369  ...
# 1                                  -499.240168  ...
# 2                                  -502.151509  ...
# 3                                  -498.355873  ...
# 4                                  -500.810606  ...
# ...                                        ...  ...
# 5285                               -499.599127  ...
# 5286                               -503.587739  ...
# 5287                               -520.667442  ...
# 5288                               -487.479567  ...
# 5289                               -492.428226  ...
#
#       secondary_cleaner.state.floatbank4_a_air  \
# 0                                    12.023554
# 1                                    12.058140
# 2                                    11.962366
# 3                                    12.033091
# 4                                    12.025367
# ...                                        ...
# 5285                                 13.995957
# 5286                                 16.749781
# 5287                                 19.994130
# 5288                                 19.958760
# 5289                                 20.034715
#
#       secondary_cleaner.state.floatbank4_a_level  \
# 0                                    -497.795834
# 1                                    -498.695773
# 2                                    -498.767484
# 3                                    -498.350935
# 4                                    -500.786497
# ...                                          ...
# 5285                                 -500.157454
# 5286                                 -496.031539
# 5287                                 -499.791312
# 5288                                 -499.958750
# 5289                                 -500.728588
#
#       secondary_cleaner.state.floatbank4_b_air  \
# 0                                     8.016656
# 1                                     8.130979
# 2                                     8.096893
# 3                                     8.074946
# 4                                     8.054678
# ...                                        ...
# 5285                                 12.069155
# 5286                                 13.365371
# 5287                                 15.101425
# 5288                                 15.026853
# 5289                                 14.914199
#
#       secondary_cleaner.state.floatbank4_b_level  \
# 0                                    -501.289139
# 1                                    -499.634209
# 2                                    -500.827423
# 3                                    -499.474407
# 4                                    -500.397500
# ...                                          ...
# 5285                                 -499.673279
# 5286                                 -499.122723
# 5287                                 -499.936252
# 5288                                 -499.723143
# 5289                                 -499.948518
#
#       secondary_cleaner.state.floatbank5_a_air  \
# 0                                     7.946562
# 1                                     7.958270
# 2                                     8.071056
# 3                                     7.897085
# 4                                     8.107890
# ...                                        ...
# 5285                                  7.977259
# 5286                                  9.288553
# 5287                                 10.989181
# 5288                                 11.011607
# 5289                                 10.986607
#
#       secondary_cleaner.state.floatbank5_a_level  \
# 0                                    -432.317850
# 1                                    -525.839648
# 2                                    -500.801673
# 3                                    -500.868509
# 4                                    -509.526725
# ...                                          ...
# 5285                                 -499.516126
# 5286                                 -496.892967
# 5287                                 -498.347898
# 5288                                 -499.985046
# 5289                                 -500.658027
#
#       secondary_cleaner.state.floatbank5_b_air  \
# 0                                     4.872511
# 1                                     4.878850
# 2                                     4.905125
# 3                                     4.931400
# 4                                     4.957674
# ...                                        ...
# 5285                                  5.933319
# 5286                                  7.372897
# 5287                                  9.020944
# 5288                                  9.009783
# 5289                                  8.989497
#
#       secondary_cleaner.state.floatbank5_b_level  \
# 0                                    -500.037437
# 1                                    -500.162375
# 2                                    -499.828510
# 3                                    -499.963623
# 4                                    -500.360026
# ...                                          ...
# 5285                                 -499.965973
# 5286                                 -499.942956
# 5287                                 -500.040448
# 5288                                 -499.937902
# 5289                                 -500.337588
#
#       secondary_cleaner.state.floatbank6_a_air  \
# 0                                    26.705889
# 1                                    25.019940
# 2                                    24.994862
# 3                                    24.948919
# 4                                    25.003331
# ...                                        ...
# 5285                                  8.987171
# 5286                                  8.986832
# 5287                                  8.982038
# 5288                                  9.012660
# 5289                                  8.988632
#
#       secondary_cleaner.state.floatbank6_a_level
# 0                                    -499.709414
# 1                                    -499.819438
# 2                                    -500.622559
# 3                                    -498.709987
# 4                                    -500.856333
# ...                                          ...
# 5285                                 -499.755909
# 5286                                 -499.903761
# 5287                                 -497.789882
# 5288                                 -500.154284
# 5289                                 -500.764937
#
# [5290 rows x 52 columns]

# %%
features_train.shape, features_test.shape
# Out:
# ((13132, 52), (5290, 52))

# %% [markdown]
# ### Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %%
pipe_lr = Pipeline([('mm',MinMaxScaler()),('lr', LinearRegression(n_jobs=-1))])
pipe_rfr = Pipeline([('mm',MinMaxScaler()),('rfr', RandomForestRegressor(n_estimators=15, random_state=12345, n_jobs=-1))])
pipe_knn = Pipeline([('mm',MinMaxScaler()),('knn', KNeighborsRegressor(n_jobs=-1))])

params_lr = dict(lr__fit_intercept=['True', 'False'])

params_rfr = dict(rfr__n_estimators=[20, 50, 100, 200],
                  rfr__min_samples_leaf=range(1,4))

params_knn = dict(knn__n_neighbors=range(5,10),
                  knn__metric=['minkowski', 'manhattan'],
                  knn__leaf_size=range(30,50,5),
                  knn__algorithm = ['auto', 'ball_tree', 'kd_tree'])


pipes = [pipe_lr, pipe_rfr, pipe_knn]
params = [params_lr, params_rfr, params_knn]
models = ['linear_regression',
          'random_forest',
          'nearest_neighbors']



for model, pipe, param in zip(models, pipes, params):
    
    search = RandomizedSearchCV(pipe, param, verbose=5, scoring=custom_scorer, cv=3, n_jobs=-1)
    
    search.fit(features_train, target_train)
    
    globals()[f'filename_{model}'] = os.path.join(save_dir, f'model.joblib.{model}')
    joblib.dump(search, globals()[f'filename_{model}'])
    
    print(model)
    print(search.best_score_)
    print(search.best_params_)
    print()
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py:266: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV] lr__fit_intercept=True ..........................................
# [CV] ............ lr__fit_intercept=True, score=-10.914, total=   0.4s
# [CV] lr__fit_intercept=True ..........................................
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV] ............ lr__fit_intercept=True, score=-10.209, total=   0.3s
# [CV] lr__fit_intercept=True ..........................................
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [CV] ............ lr__fit_intercept=True, score=-15.352, total=   0.3s
# [CV] lr__fit_intercept=False .........................................
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    1.1s remaining:    0.0s
# [CV] ........... lr__fit_intercept=False, score=-10.914, total=   0.5s
# [CV] lr__fit_intercept=False .........................................
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    1.6s remaining:    0.0s
# [CV] ........... lr__fit_intercept=False, score=-10.209, total=   0.4s
# [CV] lr__fit_intercept=False .........................................
# [CV] ........... lr__fit_intercept=False, score=-15.352, total=   0.3s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    2.3s finished
# linear_regression
# -12.158298414000589
# {'lr__fit_intercept': 'True'}
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=1 ...................
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=1, score=-9.409, total=  24.0s
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=1 ...................
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:   24.0s remaining:    0.0s
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=1, score=-8.543, total=  22.1s
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=1 ...................
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:   46.1s remaining:    0.0s
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=1, score=-13.290, total=  23.7s
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=3 ...................
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  1.2min remaining:    0.0s
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=3, score=-8.983, total=  21.0s
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=3 ...................
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:  1.5min remaining:    0.0s
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=3, score=-8.384, total=  18.3s
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=3 ...................
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=3, score=-12.861, total=  20.7s
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=2 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=2, score=-9.515, total=   8.7s
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=2 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=2, score=-8.444, total=   8.1s
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=2 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=2, score=-13.112, total=   9.1s
# [CV] rfr__n_estimators=200, rfr__min_samples_leaf=3 ..................
# [CV]  rfr__n_estimators=200, rfr__min_samples_leaf=3, score=-8.906, total= 1.4min
# [CV] rfr__n_estimators=200, rfr__min_samples_leaf=3 ..................
# [CV]  rfr__n_estimators=200, rfr__min_samples_leaf=3, score=-8.249, total= 1.3min
# [CV] rfr__n_estimators=200, rfr__min_samples_leaf=3 ..................
# [CV]  rfr__n_estimators=200, rfr__min_samples_leaf=3, score=-12.684, total= 1.4min
# [CV] rfr__n_estimators=100, rfr__min_samples_leaf=2 ..................
# [CV]  rfr__n_estimators=100, rfr__min_samples_leaf=2, score=-9.168, total=  43.2s
# [CV] rfr__n_estimators=100, rfr__min_samples_leaf=2 ..................
# [CV]  rfr__n_estimators=100, rfr__min_samples_leaf=2, score=-8.311, total=  39.6s
# [CV] rfr__n_estimators=100, rfr__min_samples_leaf=2 ..................
# [CV]  rfr__n_estimators=100, rfr__min_samples_leaf=2, score=-12.660, total=  43.3s
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=1 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=1, score=-9.806, total=   9.4s
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=1 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=1, score=-8.780, total=   8.7s
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=1 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=1, score=-13.604, total=   9.4s
# [CV] rfr__n_estimators=100, rfr__min_samples_leaf=3 ..................
# [CV]  rfr__n_estimators=100, rfr__min_samples_leaf=3, score=-8.980, total=  41.1s
# [CV] rfr__n_estimators=100, rfr__min_samples_leaf=3 ..................
# [CV]  rfr__n_estimators=100, rfr__min_samples_leaf=3, score=-8.266, total=  37.2s
# [CV] rfr__n_estimators=100, rfr__min_samples_leaf=3 ..................
# [CV]  rfr__n_estimators=100, rfr__min_samples_leaf=3, score=-12.593, total=  41.4s
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=2 ...................
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=2, score=-9.252, total=  22.0s
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=2 ...................
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=2, score=-8.297, total=  21.4s
# [CV] rfr__n_estimators=50, rfr__min_samples_leaf=2 ...................
# [CV]  rfr__n_estimators=50, rfr__min_samples_leaf=2, score=-12.928, total=  21.7s
# [CV] rfr__n_estimators=200, rfr__min_samples_leaf=1 ..................
# [CV]  rfr__n_estimators=200, rfr__min_samples_leaf=1, score=-9.160, total= 1.6min
# [CV] rfr__n_estimators=200, rfr__min_samples_leaf=1 ..................
# [CV]  rfr__n_estimators=200, rfr__min_samples_leaf=1, score=-8.453, total= 1.4min
# [CV] rfr__n_estimators=200, rfr__min_samples_leaf=1 ..................
# [CV]  rfr__n_estimators=200, rfr__min_samples_leaf=1, score=-12.911, total= 1.6min
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=3 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=3, score=-9.069, total=   8.2s
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=3 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=3, score=-8.580, total=   7.4s
# [CV] rfr__n_estimators=20, rfr__min_samples_leaf=3 ...................
# [CV]  rfr__n_estimators=20, rfr__min_samples_leaf=3, score=-13.396, total=   8.8s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 17.3min finished
# random_forest
# -9.946404770489327
# {'rfr__n_estimators': 100, 'rfr__min_samples_leaf': 3}
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] knn__n_neighbors=9, knn__metric=manhattan, knn__leaf_size=30, knn__algorithm=auto
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  knn__n_neighbors=9, knn__metric=manhattan, knn__leaf_size=30, knn__algorithm=auto, score=-10.978, total=   5.0s
# [CV] knn__n_neighbors=9, knn__metric=manhattan, knn__leaf_size=30, knn__algorithm=auto
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    5.0s remaining:    0.0s
# [CV]  knn__n_neighbors=9, knn__metric=manhattan, knn__leaf_size=30, knn__algorithm=auto, score=-10.459, total=   5.5s
# [CV] knn__n_neighbors=9, knn__metric=manhattan, knn__leaf_size=30, knn__algorithm=auto
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:   10.6s remaining:    0.0s
# [CV]  knn__n_neighbors=9, knn__metric=manhattan, knn__leaf_size=30, knn__algorithm=auto, score=-12.249, total=   5.1s
# [CV] knn__n_neighbors=6, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   15.7s remaining:    0.0s
# [CV]  knn__n_neighbors=6, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree, score=-11.497, total=   4.1s
# [CV] knn__n_neighbors=6, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:   19.8s remaining:    0.0s
# [CV]  knn__n_neighbors=6, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree, score=-10.337, total=   4.6s
# [CV] knn__n_neighbors=6, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree
# [CV]  knn__n_neighbors=6, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree, score=-11.756, total=   4.3s
# [CV] knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto, score=-11.512, total=   3.8s
# [CV] knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto, score=-10.419, total=   3.8s
# [CV] knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto, score=-11.657, total=   3.4s
# [CV] knn__n_neighbors=5, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree
# [CV]  knn__n_neighbors=5, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree, score=-11.525, total=   4.1s
# [CV] knn__n_neighbors=5, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree
# [CV]  knn__n_neighbors=5, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree, score=-10.324, total=   4.5s
# [CV] knn__n_neighbors=5, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree
# [CV]  knn__n_neighbors=5, knn__metric=minkowski, knn__leaf_size=30, knn__algorithm=kd_tree, score=-11.869, total=   3.6s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=ball_tree
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=ball_tree, score=-11.020, total=   3.5s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=ball_tree
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=ball_tree, score=-10.520, total=   3.5s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=ball_tree
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=ball_tree, score=-12.703, total=   3.2s
# [CV] knn__n_neighbors=8, knn__metric=manhattan, knn__leaf_size=40, knn__algorithm=auto
# [CV]  knn__n_neighbors=8, knn__metric=manhattan, knn__leaf_size=40, knn__algorithm=auto, score=-10.994, total=   4.3s
# [CV] knn__n_neighbors=8, knn__metric=manhattan, knn__leaf_size=40, knn__algorithm=auto
# [CV]  knn__n_neighbors=8, knn__metric=manhattan, knn__leaf_size=40, knn__algorithm=auto, score=-10.438, total=   4.6s
# [CV] knn__n_neighbors=8, knn__metric=manhattan, knn__leaf_size=40, knn__algorithm=auto
# [CV]  knn__n_neighbors=8, knn__metric=manhattan, knn__leaf_size=40, knn__algorithm=auto, score=-12.310, total=   3.9s
# [CV] knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=45, knn__algorithm=auto
# [CV]  knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=45, knn__algorithm=auto, score=-11.512, total=   3.6s
# [CV] knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=45, knn__algorithm=auto
# [CV]  knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=45, knn__algorithm=auto, score=-10.419, total=   3.9s
# [CV] knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=45, knn__algorithm=auto
# [CV]  knn__n_neighbors=7, knn__metric=minkowski, knn__leaf_size=45, knn__algorithm=auto, score=-11.657, total=   3.1s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=auto, score=-11.020, total=   4.3s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=auto, score=-10.520, total=   4.6s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=35, knn__algorithm=auto, score=-12.703, total=   4.1s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=45, knn__algorithm=kd_tree
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=45, knn__algorithm=kd_tree, score=-11.020, total=   4.3s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=45, knn__algorithm=kd_tree
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=45, knn__algorithm=kd_tree, score=-10.520, total=   4.5s
# [CV] knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=45, knn__algorithm=kd_tree
# [CV]  knn__n_neighbors=5, knn__metric=manhattan, knn__leaf_size=45, knn__algorithm=kd_tree, score=-12.703, total=   4.0s
# [CV] knn__n_neighbors=9, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=9, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto, score=-11.421, total=   3.6s
# [CV] knn__n_neighbors=9, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=9, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto, score=-10.421, total=   3.9s
# [CV] knn__n_neighbors=9, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto
# [CV]  knn__n_neighbors=9, knn__metric=minkowski, knn__leaf_size=35, knn__algorithm=auto, score=-11.560, total=   3.1s
# nearest_neighbors
# -11.13423582442077
# {'knn__n_neighbors': 9, 'knn__metric': 'minkowski', 'knn__leaf_size': 35, 'knn__algorithm': 'auto'}
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  2.0min finished

# %%
dummy_regressor_rougher = DummyRegressor(strategy="median")
dummy_regressor_rougher.fit(features_train, target_train)
dummy_rougher_pred = dummy_regressor_rougher.predict(features_test)
smape_dummy_rougher = smape(target_test, dummy_rougher_pred)
print(smape_dummy_rougher)
# Out:
# 9.463879643318961

# %%
joblib.load(filename_random_forest)
# Out:
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('mm',
#                                               MinMaxScaler(copy=True,
#                                                            feature_range=(0,
#                                                                           1))),
#                                              ('rfr',
#                                               RandomForestRegressor(bootstrap=True,
#                                                                     criterion='mse',
#                                                                     max_depth=None,
#                                                                     max_features='auto',
#                                                                     max_leaf_nodes=None,
#                                                                     min_impurity_decrease=0.0,
#                                                                     min_impurity_split=None,
#                                                                     min_samples_leaf=1,
#                                                                     min_samples_split=2,
#                                                                     m...
#                                                                     n_jobs=-1,
#                                                                     oob_score=False,
#                                                                     random_state=12345,
#                                                                     verbose=0,
#                                                                     warm_start=False))],
#                                       verbose=False),
#                    iid='warn', n_iter=10, n_jobs=-1,
#                    param_distributions={'rfr__min_samples_leaf': range(1, 4),
#                                         'rfr__n_estimators': [20, 50, 100,
#                                                               200]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False,
#                    scoring=make_scorer(smape, greater_is_better=False),
#                    verbose=5)

# %%
smape(target_test, joblib.load(filename_random_forest).predict(features_test))
# Out:
# 9.801370820331694

# %% [markdown]
# **Вывод**
#
# Проверку на адекватность лучшая модель не прошла, по всей видимости либо задача просто не выполнима, в рамках машинного обучения, но как мне кажется модель оказалась просто переполнена не целевыми фичами, которые не влияют на целевой показатель, поэтому испытывает сложности в предсказаниях.
